# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import skdim
import numpy as np

from plot_utils import plot_2d, plot_3d

plt.style.use("science")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
random_state = 0

# %%
S_points, S_color = datasets.make_s_curve(n_samples=1000, noise=0.0, random_state=random_state)
plot_3d(S_points, S_color, "S-curve")

# %%
swiss_roll_points, colors = datasets.make_swiss_roll(n_samples=1000, noise=0.0, random_state=random_state)

# %%
plot_3d(swiss_roll_points, colors, "Swiss Roll")

# %%
ball = skdim.datasets.swissRoll3Sph(1000, 0)
ball.shape
# Out:
# (1000, 4)

# %%
fig, ax = plt.subplots(figsize=(6, 6))
plot_3d(ball, None, "")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [67], line 2
#       1 fig, ax = plt.subplots(figsize=(6, 6))
# ----> 2 plot_3d(ball, None, "")
#       3 plt.show()
#
# File ~/LaTeXProjects/Bachelor-Thesis/python/plot_utils.py:8, in plot_3d(points, points_color, title)
#       7 def plot_3d(points, points_color, title):
# ----> 8     x, y, z = points.T
#      10     fig, ax = plt.subplots(
#      11         figsize=(6, 6),
#      12         facecolor="white",
#      13         tight_layout=True,
#      14         subplot_kw={"projection": "3d"},
#      15     )
#      16     fig.suptitle(title, size=16)
#
# ValueError: too many values to unpack (expected 3)
